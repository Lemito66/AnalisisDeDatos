# %% [markdown]
# # Presentación e introducción al entorno de Python

# %% [markdown]
# <div style="text-align: right">por <a href="https://www.linkedin.com/in/angel-astudillo-aguilar" target="_blank">Angel Xavier Astudillo Aguilar</a></div>

# %% [markdown]
# Cuánto has programado antes? Encuesta: https://forms.gle/wiQZQmnPw7AqArh87

# %% [markdown]
# # Pequeña Presentación.
# <img width=200 src="https://media.istockphoto.com/id/1183215581/es/vector/icono-de-personas-logotipo-aislado-sobre-fondo-blanco.jpg?s=170667a&w=0&k=20&c=S3nPXGMKb5kkQj2iA9d26rbxrvXOcwXwZjjHckUL_Qc=">

# %% [markdown]
# # Cuestiones relevantes sobre el curso
#  - sesiones de 2h con una pausa optativa
#  - sesiones grabadas
#  - micrófono silenciado (pero pueden alzar la mano para poder hablar)
#  - video abierto
#  - las preguntas pueden ser públicas o privadas (vía email)
#  - resolución de dudas [ChatGPT](https://chat.openai.com/) y [Stack Overflow](https://stackoverflow.com/)

# %% [markdown]
# Ten una libreta a mano para tomar notas durante la sesión!

# %% [markdown]
# <img width=300 src="https://png.pngtree.com/png-clipart/20210528/ourlarge/pngtree-cartoon-character-learning-notepad-illustration-png-image_3375178.jpg">

# %% [markdown]
# Habrán 10 sesiones prácticas (talleres) pero con teoría necesaria:
# # Contenido del curso
#  1. Presentación e introducción al entorno de Python
#  2. Introducción a Python
#  3. Variable y Tipos de datos más comunes
#  4. Operadores aritméticos y textuales
#  5. Control de flujo: condicionales
#  6. Control de flujo: bucles
#  7. Funciones
#  8. Librerías en Python
#  9. Pandas para el análisis de datos
#  10. Análisis de datos básico

# %% [markdown]
# ![Screenshot 2023-06-14 4.33.29 PM-fotor-2023061417126.png](data:image/png;base64,...)

# %% [markdown]
# # Taller 1
# Enlace a Colab: https://colab.research.google.com/

# %% [markdown]
# ![Screenshot 2023-06-14 5.57.36 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-06-14 5.57.36 PM-fotor-2023061418023.png](data:image/png;base64,...)

# %% [markdown]
# * Abrir nuevo notebook
# * Barra izquierda
#   * Arriba: TOC, buscar, variables, "files"
#   * Abajo: Códigos a la carta, paleta de comandos, terminal
# * Barra superior: + Code, + Text, kernel info
# * Celdas
#   * Texto (Markdown): Cabeceras (#), negritas, cursivas, formato código, links, imágenes, Indentación, listas numéricas, listas no numéricas, separador horizontal, LaTeX, Emojis, preview position
#     * [Interesante página](https://www.markdownguide.org/)
#     * [Cheat sheet](https://www.markdownguide.org/cheat-sheet/)
#     * [versión en Español](https://markdown.es/)
#   * Configuración: subir, bajar, Link, comentarios, config del editor, cerrar el editor de MD, abrir celda en un tab, eliminar celda, seleccionar, copiar, cortar
#   * Código: formularios, código y resultados. Imprimir

# %% [markdown]
# * Crear sección con nombre del curso
# * Crear celda de texto con nombre u enlazarlo con un link a linkedIn
# * Agregamos una imagen de google referente al análisis de datos
# * Creamos una variable simple
# * Vemos que la variable en la sección de variables
# * Impimimos con print
# * Imprimimos con poner la variable
# * Creamos otra variable
# * Intentamos poner las 2 variables a ver que pasa

# %% [markdown]
# # Próxima Clase
# * Introducción a Python
# * Variables y tipos de datos más comunes
