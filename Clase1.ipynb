# %% [markdown]
# # Análisis de datos con python

# %% [markdown]
# [Emill Logroño ](https://www.linkedin.com/in/emill-logro%C3%B1o-168892200/)
#
# ![descarga.jpg](data:image/jpeg;base64,...)

# %%
simple = 5

# %% [markdown]
# Imprimimos la variable

# %%
print(simple)
# Out:
# 5

# %% [markdown]
# # Truco

# %%
# Truco
simple
# Out:
# 5

# %% [markdown]
# Creamos otra variable

# %%
other_variable = 55

# %% [markdown]
# Probar las dos variables, no se pueden

# %%
simple
other_variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 simple
#       2 other_variable
#
# NameError: name 'simple' is not defined

# %%
print(simple)
print(other_variable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(simple)
#       2 print(other_variable)
#
# NameError: name 'simple' is not defined
