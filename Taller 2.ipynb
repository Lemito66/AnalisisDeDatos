# %% [markdown]
# # Introducción a Python

# %% [markdown]
# <div style="text-align: right">por <a href="https://www.linkedin.com/in/angel-astudillo-aguilar" target="_blank">Angel Xavier Astudillo Aguilar</a></div>

# %% [markdown]
# # Recapitulación
#  1. Presentación e introducción al entorno de Python
#     * Presentaciones
#     * Cuestiones relevantes del curso
#     * Taller de reconocimiento

# %% [markdown]
# ## Python

# %% [markdown]
#  * Creado en 1991
#  * Simplicidad y legibilidad entre sus principales objetivos
#  * Popular hoy para desarrollo web, automatización de procesos, análisis de datos
#  * Instagram, Spotify, Netflix, Google y Dropbox, entre otros, lo utilizan

# %% [markdown]
#  * Funciona en Windows, Mac, Linux
#  * Open source
#  * Gran comunidad de desarrolladores
#  * Librerías cuantiosas (biología, química, economía, estructuras, cálculo simbólico, análisis de textos, análisis de imágenes...)

# %% [markdown]
# libros para aprender sintaxis de python

# %% [markdown]
# ### Jupyter notebook

# %% [markdown]
# Ésto que ves es un [jupyter notebook](https://jupyter.org/).
#  - Un híbrido entre Power Point y entorno de programación
#  - Cuyos archivos tienen extensión `.ipynb`
#  - Para verlo, puedes:
#    - descargar Python y jupyter o
#    - verlo (y modificarlo) en [Google Colab](https://colab.research.google.com/?hl=es)

# %% [markdown]
# ### Archivos .py

# %% [markdown]
# Podemos trabajar directamente con archivos de extensión `.py`
#  1. escribir un script de python
#  2. guardarlo como `mi_script.py`
#  3. ejecutarlo desde la terminal utilizando `python mi_script.py` (a veces `python3`)

# %% [markdown]
# ## Probando el entorno del notebook

# %% [markdown]
# ###### Guardamos el contenido del notebook.
# *Aplastamos Ctrl + s.*

# %% [markdown]
# ###### Creamos una nueva celda.
# *Damos click en el botón con el ícono de más text (+ Text).*

# %% [markdown]
# ###### Borramos una celda.
# *Damos click en el botón con el ícono de basurero.*

# %% [markdown]
# *bórrame (soy la celda que tienes que borrar)*

# %% [markdown]
# ###### Copiamos una celda.
# *Damos click en el botón con  tres puntos y luego **Copy cell** o aplatamos Ctrl + c.*

# %% [markdown]
# *Cópiame*

# %% [markdown]
# ###### Pegamos una celda.
# *Aplastamos Ctrl + v.*

# %% [markdown]
# ###### Movemos una celda hacia arriba.
# *Damos click en el botón con el ícono de flechita hacia arriba.*

# %% [markdown]
# *mueve la celda de abajo hacia arriba*

# %% [markdown]
# *muéveme hacia arriba*

# %% [markdown]
# ###### Movemos una celda hacia abajo.
# *Damos click en el botón con el ícono de flechita hacia abajo.*

# %% [markdown]
# *muéveme hacia abajo*

# %% [markdown]
# *mueve la celda de arriba hacia abajo*

# %% [markdown]
# Para ejecutar una celda (tanto de código como de texto) hay que aplastar las teclas *shift* + *enter*

# %% [markdown]
# ## Introducción a python

# %% [markdown]
# ### Comentarios función print() y sintaxis básica.

# %% [markdown]
# Los comentarios son líneas de código que python omite ejecutar cuando empieza a correr un código. <br>
# En python se comentan las líneas de código usando el caracter numeral (#).

# %%
# Esto es un comentario.

# %% [markdown]
# **TIP:** Para mostrar el número de línea en las celdas, ir a **Tools**->**Settings**->**Editor**->**show Line Numbers**.

# %% [markdown]
# La función **print()** es utilizada en python para imprimir en pantalla lo que se encuentre dentro de sus paréntesis. <br>
# Puede imprimir números textos, entre otros formatos legibles.<br>
# *A continuación tenemos 2 celdas con ejemplos para imprimir y una celda vacía para probar imprimiendo cualquier contenido.*

# %%
print(30)

# %%
print("Hola mundo!")

# %% [markdown]
# En las celdas se pueden escribir más de una línea y se ejecutarían de manera secuencial *(en orden, una detrás de otra)*.
# ![codigo](./images/codigo.svg)
# El conjunto de **líneas de código** se llama **código**.

# %%
print(30)
print("Hola mundo!")

# %%
print("Hola mundo!")
print(30)

# %%
# print(30)
print("Hola mundo!")

# %%
# Imprimimos en pantalla "Hola mundo!"
print("Hola mundo!")

# %% [markdown]
# **TIP:** Las líneas en blanco simplemente no afectan la ejecución del código no tiene ningún incidencia con el código en general.

# %%
print(30)

print("Hola mundo!")

# %%
print("Hola mundo!")

print(30)

# %% [markdown]
# **TIP:** Las **sentencias** u *oraciones* en Python se escriben una debajo de la otra, no está permitido escribir más de una **sentencia** por **línea**.

# %%
print(30)print("Hola mundo!")

# %%
print(30) print("Hola mundo!")

# %% [markdown]
# **TIP:** Hay que tener cuidado con la indentación del código.

# %%
print(30)
    print("Hola mundo!")

# %% [markdown]
# ## 3. Variables y tipos de datos
# ### Tipos de datos
# Una variable es un espacio de memoria donde se almacenará el valor que le asignemos a dicha variable, podemos ver gráficamente en la imagen de abajo. Donde el **valor** de **20** se almacenará en el primer cuadrante de **memoria** y se refirirá a este cuadrante como **result** según este ejemplo. <br>
# Se llaman **variables**, porque a pesar de reservar un espacio de memoria, el **valor** que se almacena en ese **espacio de memoria** puede cambiar *(variar)* con respecto al tiempo.
# ![variables](./images/variables.png)
# Para crear una variable en Python se escribe el **nombre de la variable**, a continuación el signo igual **=** y luego el **valor** que se le quiere asignar a dicha variable. <br>
# *El signo igual **=** es considerado como el **operador** de asignación.*

# %%
result = 20

# %% [markdown]
# **TIP:** Las variables creadas en una **celda** de un **cuaderno** pueden ser utilizadas en **todas las celdas** de ese mismo cuadeno. <br>
# **TIP:** Para mostrar en pantalla el **contenido** de una **variable** podemos usar la función **print()** y dentro el **nombre de la variable** que queremos imprimir.

# %%
print(result)

# %% [markdown]
# **TIP:** Para mostrar en pantalla el **contenido** de una **variable** usando celdas podemos simplemente poner el **nombre de la variable** que queremos imprimir en la última línea de la celda y esta se imprimirá.

# %%
# cambiamos el contenido de result de 20 a 30.
result = 30
result

# %% [markdown]
# **TIP:** Los nombres de las variables tienen una propiedad llama **Case sensitive** donde el cambio entre minúsculas y mayúsculas afectan a las **variables**.

# %%
print(Result)

# %% [markdown]
# ### Tipos de datos
# Los **valores** asignados a una **variable** son también conocidos como **datos**. <br>
# Estos **datos** podrían ser de distintos **tipos**. Los **tipos de datos primitivos** son:
# - **int** ejemplo: 2

# %%
dos_int = 2
print(dos_int)

# %% [markdown]
# - **float** ejemplo: 2.0

# %%
dos_float = 2.0
print(dos_float)

# %% [markdown]
# - **str** ejemplo: '2' o 'dos' o "2" o "dos"

# %%
dos_str = '2'
print(dos_str)

# %%
dos_str = "2"
print(dos_str)

# %%
dos_str = 'dos'
print(dos_str)

# %%
dos_str = "dos"
print(dos_str)

# %% [markdown]
# - **bool** ejemplo: True o False <br>
#
# **TIP:** Los **valores** booleanos tienen la primera letra en mayúsculas.

# %%
verdadero = True
print(verdadero)

# %%
falso = False
print(falso)

# %%
verdadero = true

# %%
falso = false

# %% [markdown]
# Los **tipos de datos primitivos** son considerados de esta manera porque el resto de **tipos de datos** son construidos como una composición de estos **tipos de datos**. <br>
#
# ---
#
# Hay otros **tipos de datos** no primitivos ampliamente utilizados en Python *(algunos de estos los veremos más adelante en el curso)*:
# - **list** ejemplo: [1,2,3]
# - **dict** ejemplo: { 'key':1,'key2':'value'}
# - **Series**
# - **DataFrame**
# - **etc**

# %% [markdown]
# Hemos comentado que los **datos** tienen distintos tipos, pero ¿habría forma de verificar que **tipo de dato** es una **variable**?.<br>
# Para esto podemos utilizar la función **type()** que devuelve el **tipo de dato** del **valor** o **variable** que se le pasa dentro de los paréntesis.

# %%
type(2)

# %%
# previamente habíamos definido dos_int de esta manera
# dos_int = 2
type(dos_int)

# %%
# previamente habíamos definido dos_float de esta manera
# dos_float = 2.0
type(dos_float)

# %%
# previamente habíamos definido dos_str de esta manera
# dos_str = "dos"
type(dos_str)

# %%
# para este ejemplo cambiamos el valor de dos_str
dos_str = '2'
type(dos_str)

# %%
# previamente habíamos definido verdadero de esta manera
# verdadero = True
type(verdadero)

# %%
# previamente habíamos definido falso de esta manera
# falso = False
type(falso)

# %% [markdown]
# Y si tengo una variable con un **tipo de dato** que no me conviene y quiero cambiarlo, ¿cómo podría hacerlo?. <br>
# Existen ciertas funciones que me convierten un **valor** con un **tipo de dato** a otro **tipo de dato** de interes.
# - función **int()**: devuelve en **int** el **valor** o **contenido de  variable** que se le pasa dentro de los paréntesis. Sí el **valor** pasado en paréntesis **no tiene base 10** o en otras palabras no se puede convertir en *entero* la función bota un **error**.<br>
# **TIP:** el **valor bool True** es considerado **1** y el **valor bool False** es considerado **0**

# %%
# 1. imprimimos el valor de '2' en formato str
print('2')

# 2. verificamos el tipo de dato de '2'
print(type('2'))

# 3. convertimos el '2' str en int o entero
print(int('2'))

# 4. verificamos el tipo de dato del '2' convertido en int o entero
print(type(int('2')))

# %%
# previamente habíamos definido dos_float de esta manera
# dos_float = 2.0

# 1. imprimimos el valor de 2.0 en formato float
print(dos_float)

# 2. verificamos el tipo de dato de 2.0
print(type(dos_float))

# 3. convertimos el 2.0 float en int o entero
print(int(dos_float))

# 4. verificamos el tipo de dato del 2.0 convertido en int o entero
print(type(int(dos_float)))

# %%
# previamente habíamos definido dos_str de esta manera
# dos_str = '2'

# 1. imprimimos el valor de '2' en formato str
print(dos_str)

# 2. verificamos el tipo de dato de '2'
print(type(dos_str))

# 3. convertimos el '2' str en int o entero
print(int(dos_str))

# 4. verificamos el tipo de dato del '2' convertido en int o entero
print(type(int(dos_str)))

# %%
# para este ejemplo cambiamos el valor de dos_str
dos_str = "dos"

# 1. imprimimos el valor de "dos" en formato str
print(dos_str)

# 2. verificamos el tipo de dato de "dos"
print(type(dos_str))

# 3. convertimos el "dos" str en int o entero; est línea nos devolvería un ERROR.
print(int(dos_str))

# 4. Esta línea no tendría sentido ya que la anterior no se podría ejecutar
# print(type(int(dos_str)))

# %%
# previamente habíamos definido verdadero de esta manera
# verdadero = True

# 1. imprimimos el valor de la variable verdadero en formato bool
print(verdadero)

# 2. verificamos el tipo de dato de verdadero
print(type(verdadero))

# 3. convertimos el verdadero bool en int o entero
print(int(verdadero))

# 4. verificamos el tipo de dato del verdadero convertido en int o entero
print(type(int(verdadero)))

# %%
# previamente habíamos definido falso de esta manera
# falso = False

# 1. imprimimos el valor de la variable falso en formato bool
print(falso)

# 2. verificamos el tipo de dato de falso
print(type(falso))

# 3. convertimos el falso bool en int o entero
print(int(falso))

# 4. verificamos el tipo de dato del falso convertido en int o entero
print(type(int(falso)))

# %%
# previamente habíamos definido dos_int de esta manera
# dos_int = 2

# 1. imprimimos el valor de 2 en formato int o entero
print(dos_int)

# 2. verificamos el tipo de dato de 2
print(type(dos_int))

# 3. convertimos el 2 int en int o entero
print(int(dos_int))

# 4. verificamos el tipo de dato del 2 convertido en int o entero
print(type(int(dos_int)))

# %% [markdown]
# - función **float()**: devuelve en **float** el **valor** o **contenido de  variable** que se le pasa dentro de los paréntesis. Sí el **valor** pasado en paréntesis **no tiene base 10** o en otras palabras no se puede convertir en *decimal* la función bota un **error**.<br>
#
# **TIP:** el **valor bool True** es considerado **1.0** y el **valor bool False** es considerado **0.0**

# %%
# 1. imprimimos el valor de '2' en formato str
print('2')

# 2. verificamos el tipo de dato de '2'
print(type('2'))

# 3. convertimos el '2' str en float o decimal
print(float('2'))

# 4. verificamos el tipo de dato del '2' convertido en float o decimal
print(type(float('2')))

# %%
# previamente habíamos definido dos_int de esta manera
# dos_int = 2

# 1. imprimimos el valor de 2 en formato int
print(dos_int)

# 2. verificamos el tipo de dato de 2
print(type(dos_int))

# 3. convertimos el 2 int en float o decimal
print(float(dos_int))

# 4. verificamos el tipo de dato del 2 convertido en float o decimal
print(type(float(dos_int)))

# %%
# previamente habíamos definido dos_str de esta manera
dos_str = '2'

# 1. imprimimos el valor de '2' en formato str
print(dos_str)

# 2. verificamos el tipo de dato de '2'
print(type(dos_str))

# 3. convertimos el '2' str en float o decimal
print(float(dos_str))

# 4. verificamos el tipo de dato del '2' convertido en float o decimal
print(type(float(dos_str)))

# %%
# previamente habíamos definido verdadero de esta manera
# verdadero = True

# 1. imprimimos el valor de la variable verdadero en formato bool
print(verdadero)

# 2. verificamos el tipo de dato de verdadero
print(type(verdadero))

# 3. convertimos el verdadero bool en float o decimal
print(float(verdadero))

# 4. verificamos el tipo de dato del verdadero convertido en float o decimal
print(type(float(verdadero)))

# %%
# previamente habíamos definido falso de esta manera
# falso = False

# 1. imprimimos el valor de la variable falso en formato bool
print(falso)

# 2. verificamos el tipo de dato de falso
print(type(falso))

# 3. convertimos el falso bool en float o decimal
print(float(falso))

# 4. verificamos el tipo de dato del falso convertido en float o decimal
print(type(float(falso)))

# %%
# previamente habíamos definido dos_float de esta manera
# dos_float = 2.0

# 1. imprimimos el valor de 2.0 en formato float o decimal
print(dos_float)

# 2. verificamos el tipo de dato de 2.0
print(type(dos_float))

# 3. convertimos el 2.0 float en float o decimal
print(float(dos_float))

# 4. verificamos el tipo de dato del 2.0 convertido en float o decimal
print(type(float(dos_float)))

# %% [markdown]
# - función **str()**: devuelve en **str** el **valor** o **contenido de  variable** que se le pasa dentro de los paréntesis.<br>

# %%
# 1. imprimimos el valor de 2 en formato int
print(2)

# 2. verificamos el tipo de dato de 2
print(type(2))

# 3. convertimos el 2 int en str o texto
print(str(2))

# 4. verificamos el tipo de dato del 2 convertido en str o texto
print(type(str(2)))

# %%
# previamente habíamos definido dos_int de esta manera
# dos_int = 2

# 1. imprimimos el valor de 2 en formato int o entero
print(dos_int)

# 2. verificamos el tipo de dato de 2
print(type(dos_int))

# 3. convertimos el 2 int en str o texto
print(str(dos_int))

# 4. verificamos el tipo de dato del 2 convertido en str o texto
print(type(str(dos_int)))

# %%
# previamente habíamos definido dos_float de esta manera
# dos_float = 2.0

# 1. imprimimos el valor de 2.0 en formato float o decimal
print(dos_float)

# 2. verificamos el tipo de dato de 2.0
print(type(dos_float))

# 3. convertimos el 2.0 float en str o texto
print(str(dos_float))

# 4. verificamos el tipo de dato del 2.0 convertido en str o texto
print(type(str(dos_float)))

# %%
# previamente habíamos definido verdadero de esta manera
# verdadero = True

# 1. imprimimos el valor de True en formato bool
print(verdadero)

# 2. verificamos el tipo de dato de True
print(type(verdadero))

# 3. convertimos el True bool en str o texto
print(str(verdadero))

# 4. verificamos el tipo de dato del True convertido en str o texto
print(type(str(verdadero)))

# %%
# previamente habíamos definido falso de esta manera
# falso = False

# 1. imprimimos el valor de False en formato bool
print(falso)

# 2. verificamos el tipo de dato de False
print(type(falso))

# 3. convertimos el False bool en str o texto
print(str(falso))

# 4. verificamos el tipo de dato del False convertido en str o texto
print(type(str(falso)))

# %%
# previamente habíamos definido dos_str de esta manera
# dos_str = '2'

# 1. imprimimos el valor de '2' en formato str
print(dos_str)

# 2. verificamos el tipo de dato de '2'
print(type(dos_str))

# 3. convertimos el '2' str en str o texto
print(str(dos_str))

# 4. verificamos el tipo de dato del '2' convertido en str o texto
print(type(str(dos_str)))

# %% [markdown]
# - función **bool()**: devuelve en **bool** el **valor** o **contenido de  variable** que se le pasa dentro de los paréntesis.<br>
# **REGLA:** **valores numéricos** que sean *distintos* de **cero** serán convertidos en **True** y sólo si un **valor** es **cero** al convertirlo en **bool** será **False**.<br>
#
# **REGLA:** **valores textuales** que sean *distintos* de **vacío ('')** serán convertidos en **True** y sólo si un **valor** es **vacío ('')** al convertirlo en **bool** será **False**.

# %%
# 1. imprimimos el valor de 2 en formato int
print(2)

# 2. verificamos el tipo de dato de 2
print(type(2))

# 3. convertimos el 2 int en bool
print(bool(2))

# 4. verificamos el tipo de dato del 2 convertido en bool
print(type(bool(2)))

# %%
# previamente habíamos definido dos_int de esta manera
# dos_int = 2

# 1. imprimimos el valor de 2 en formato int o entero
print(dos_int)

# 2. verificamos el tipo de dato de 2
print(type(dos_int))

# 3. convertimos el 2 int en bool
print(bool(dos_int))

# 4. verificamos el tipo de dato del 2 convertido en bool
print(type(bool(dos_int)))

# %%
# previamente habíamos definido dos_float de esta manera
# dos_float = 2.0

# 1. imprimimos el valor de 2.0 en formato float o decimal
print(dos_float)

# 2. verificamos el tipo de dato de 2.0
print(type(dos_float))

# 3. convertimos el 2.0 float en bool
print(bool(dos_float))

# 4. verificamos el tipo de dato del 2.0 convertido en bool
print(type(bool(dos_float)))

# %%
bool(verdadero)
# previamente habíamos definido verdadero de esta manera
# verdadero = True

# 1. imprimimos el valor de True en formato bool
print(verdadero)

# 2. verificamos el tipo de dato de True
print(type(verdadero))

# 3. convertimos el True bool en bool
print(bool(verdadero))

# 4. verificamos el tipo de dato del True convertido en bool
print(type(bool(verdadero)))

# %%
# previamente habíamos definido dos_str de esta manera
# dos_str = '2'

# 1. imprimimos el valor de '2' en formato str
print(dos_str)

# 2. verificamos el tipo de dato de '2'
print(type(dos_str))

# 3. convertimos el '2' str en bool
print(bool(dos_str))

# 4. verificamos el tipo de dato del '2' convertido en bool
print(type(bool(dos_str)))

# %%
# 1. imprimimos el valor de 0 en formato int
print(0)

# 2. verificamos el tipo de dato de 0
print(type(0))

# 3. convertimos el 0 int en bool
print(bool(0))

# 4. verificamos el tipo de dato del 0 convertido en bool
print(type(bool(0)))

# %%
# 1. imprimimos el valor de 0.0 en formato float o decimal
print(0.0)

# 2. verificamos el tipo de dato de 0.0
print(type(0.0))

# 3. convertimos el 0.0 float en bool
print(bool(0.0))

# 4. verificamos el tipo de dato del 0.0 convertido en bool
print(type(bool(0.0)))

# %%
# 1. imprimimos el valor de '' en formato str
print('')

# 2. verificamos el tipo de dato de ''
print(type(''))

# 3. convertimos el '' str en bool
print(bool(''))

# 4. verificamos el tipo de dato del '' convertido en bool
print(type(bool('')))

# %% [markdown]
# # Próxima Clase
# * Operadores aritméticos y textuales
