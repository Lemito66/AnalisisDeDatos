# %% [markdown]
# Crear sección con nombre del curso

# %% [markdown]
# # Análisis de datos básico con Python

# %% [markdown]
# Crear celda de texto con nombre y enlazarlo con un link a linkedIn

# %% [markdown]
# [Angel Astudillo](https://www.linkedin.com/in/angel-astudillo-aguilar-4462834b/)

# %% [markdown]
# Agregamos una imagen de google referente al análisis de datos

# %% [markdown]
# ![analisis de datos panamenos.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Creamos una variable simple

# %%
simple = 14

# %% [markdown]
# Vemos la variable en la sección de variables

# %% [markdown]
# Impimimos la variable creada previamente con print

# %%
print(simple)
# Out:
# 14

# %% [markdown]
# Imprimimos la variable con sólo poner el nombre de la variable

# %% [markdown]
# # OjO con el truco

# %%
simple
# Out:
# 14

# %% [markdown]
# Creamos otra variable

# %%
otra_variable = 30

# %% [markdown]
# Intentamos poner las 2 variables a ver que pasa

# %%
simple
otra_variable
# Out:
# 30

# %%
print(simple)
print(otra_variable)
# Out:
# 14
# 30
